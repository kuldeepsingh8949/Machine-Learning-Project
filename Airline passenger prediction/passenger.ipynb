# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/upflairs-pvt-ltd/1st_june_data_science/master/customer_satisfaction/cust_satisfaction.csv")
df.head()
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3  Female     Loyal Customer  Business travel  Business
# 4    Male     Loyal Customer  Business travel  Business
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 2                satisfied   26             1142                       5
# 3  neutral or dissatisfied   25              562                       2
# 4                satisfied   61              214                       3
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
# 2                 4            5                           0
# 3                 3            2                          11
# 4                 4            3                           0
#
#    Arrival Delay in Minutes
# 0                      18.0
# 1                       6.0
# 2                       0.0
# 3                       9.0
# 4                       0.0

# %%
df.info()  # https://raw.githubusercontent.com/upflairs-pvt-ltd/1st_june_data_science/master/customer_satisfaction/cust_satisfaction.csv
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103904 non-null  object
#  1   Customer Type               103904 non-null  object
#  2   Type of Travel              103904 non-null  object
#  3   Class                       103904 non-null  object
#  4   satisfaction                103904 non-null  object
#  5   Age                         103904 non-null  int64
#  6   Flight Distance             103904 non-null  int64
#  7   Inflight entertainment      103904 non-null  int64
#  8   Baggage handling            103904 non-null  int64
#  9   Cleanliness                 103904 non-null  int64
#  10  Departure Delay in Minutes  103904 non-null  int64
#  11  Arrival Delay in Minutes    103594 non-null  float64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 9.5+ MB

# %%
df.shape
# Out:
# (103904, 12)

# %%
# similar data of customer
df.duplicated().sum()
# Out:
# np.int64(172)

# %%
# null value
df.isnull().sum()
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# satisfaction                    0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      310
# dtype: int64

# %%
# remove null value
df.dropna(inplace=True)

# %%
# now check null value
df.isnull().sum()
# Out:
# Gender                        0
# Customer Type                 0
# Type of Travel                0
# Class                         0
# satisfaction                  0
# Age                           0
# Flight Distance               0
# Inflight entertainment        0
# Baggage handling              0
# Cleanliness                   0
# Departure Delay in Minutes    0
# Arrival Delay in Minutes      0
# dtype: int64

# %%
Female = df[df['Gender']=='Female']
Male = df[df['Gender']=='Male']

# %%
Male.shape , Female.shape
# Out:
# ((51018, 12), (52576, 12))

# %%
Male['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    28590
# satisfied                  22428
# Name: count, dtype: int64

# %%
Female['Class'].value_counts()
# Out:
# Class
# Business    24868
# Eco         23776
# Eco Plus     3932
# Name: count, dtype: int64

# %%
sns.countplot(x='Customer Type',data=df,hue='Gender')
plt.show()

# %%
sns.countplot(x='satisfaction',data=df,hue='Gender')
plt.show()

# %%
sns.countplot(x='Class',data=df,hue='Gender')
plt.show()

# %%
sns.countplot(x='Age',data=df,hue='Gender')
plt.show()

# %%
sns.relplot(x='Departure Delay in Minutes',y='Arrival Delay in Minutes',data=df,)
plt.show()

# %%
# filter the data in the basis of class 
sns.relplot(x='Departure Delay in Minutes',y='Arrival Delay in Minutes',data=df,col='Class')
plt.show()

# %%
df['Class'].value_counts()
# Out:
# Class
# Business    49533
# Eco         46593
# Eco Plus     7468
# Name: count, dtype: int64

# %%
df['Age'].min()
# Out:
# np.int64(7)

# %%
df['Age'].max()
# Out:
# np.int64(85)

# %%
sns.histplot(df['Age'],bins=[5,25,45,65,85],color='b')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.countplot(x='Inflight entertainment',data=df,hue='Gender')
plt.show()

# %%
sns.countplot(x='Baggage handling',data=df,hue='Gender')
plt.title('Baggage handling')
plt.show()

# %%
sns.countplot(x='Cleanliness',data=df,hue='Gender')
plt.title('Baggage handling')
plt.show()

# %%
sns.countplot(x='Cleanliness',data=df,hue='Gender')
plt.show()

# %%
sns.countplot(df['satisfaction'])
plt.title("Blance or Inbalance")
plt.show()

# %%
df['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    58697
# satisfied                  44897
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3  Female     Loyal Customer  Business travel  Business
# 4    Male     Loyal Customer  Business travel  Business
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 2                satisfied   26             1142                       5
# 3  neutral or dissatisfied   25              562                       2
# 4                satisfied   61              214                       3
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
# 2                 4            5                           0
# 3                 3            2                          11
# 4                 4            3                           0
#
#    Arrival Delay in Minutes
# 0                      18.0
# 1                       6.0
# 2                       0.0
# 3                       9.0
# 4                       0.0

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,OrdinalEncoder

# %%
df.head()
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3  Female     Loyal Customer  Business travel  Business
# 4    Male     Loyal Customer  Business travel  Business
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 2                satisfied   26             1142                       5
# 3  neutral or dissatisfied   25              562                       2
# 4                satisfied   61              214                       3
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
# 2                 4            5                           0
# 3                 3            2                          11
# 4                 4            3                           0
#
#    Arrival Delay in Minutes
# 0                      18.0
# 1                       6.0
# 2                       0.0
# 3                       9.0
# 4                       0.0

# %%
pd.get_dummies(df).astype(int)
# Out:
#         Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 0        13              460                       5                 4
# 1        25              235                       1                 3
# 2        26             1142                       5                 4
# 3        25              562                       2                 3
# 4        61              214                       3                 4
# ...     ...              ...                     ...               ...
# 103899   23              192                       2                 4
# 103900   49             2347                       5                 5
# 103901   30             1995                       4                 4
# 103902   22             1000                       1                 1
# 103903   27             1723                       1                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                 5                          25                        18
# 1                 1                           1                         6
# 2                 5                           0                         0
# 3                 2                          11                         9
# 4                 3                           0                         0
# ...             ...                         ...                       ...
# 103899            2                           3                         0
# 103900            4                           0                         0
# 103901            4                           7                        14
# 103902            1                           0                         0
# 103903            1                           0                         0
#
#         Gender_Female  Gender_Male  Customer Type_Loyal Customer  \
# 0                   0            1                             1
# 1                   0            1                             0
# 2                   1            0                             1
# 3                   1            0                             1
# 4                   0            1                             1
# ...               ...          ...                           ...
# 103899              1            0                             0
# 103900              0            1                             1
# 103901              0            1                             0
# 103902              1            0                             0
# 103903              0            1                             1
#
#         Customer Type_disloyal Customer  Type of Travel_Business travel  \
# 0                                     0                               0
# 1                                     1                               1
# 2                                     0                               1
# 3                                     0                               1
# 4                                     0                               1
# ...                                 ...                             ...
# 103899                                1                               1
# 103900                                0                               1
# 103901                                1                               1
# 103902                                1                               1
# 103903                                0                               1
#
#         Type of Travel_Personal Travel  Class_Business  Class_Eco  \
# 0                                    1               0          0
# 1                                    0               1          0
# 2                                    0               1          0
# 3                                    0               1          0
# 4                                    0               1          0
# ...                                ...             ...        ...
# 103899                               0               0          1
# 103900                               0               1          0
# 103901                               0               1          0
# 103902                               0               0          1
# 103903                               0               1          0
#
#         Class_Eco Plus  satisfaction_neutral or dissatisfied  \
# 0                    1                                     1
# 1                    0                                     1
# 2                    0                                     0
# 3                    0                                     1
# 4                    0                                     0
# ...                ...                                   ...
# 103899               0                                     1
# 103900               0                                     0
# 103901               0                                     1
# 103902               0                                     1
# 103903               0                                     1
#
#         satisfaction_satisfied
# 0                            0
# 1                            0
# 2                            1
# 3                            0
# 4                            1
# ...                        ...
# 103899                       0
# 103900                       1
# 103901                       0
# 103902                       0
# 103903                       0
#
# [103594 rows x 18 columns]

# %%
pd.get_dummies(df,drop_first="if_binary").astype(int)
# Out:
#         Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 0        13              460                       5                 4
# 1        25              235                       1                 3
# 2        26             1142                       5                 4
# 3        25              562                       2                 3
# 4        61              214                       3                 4
# ...     ...              ...                     ...               ...
# 103899   23              192                       2                 4
# 103900   49             2347                       5                 5
# 103901   30             1995                       4                 4
# 103902   22             1000                       1                 1
# 103903   27             1723                       1                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                 5                          25                        18
# 1                 1                           1                         6
# 2                 5                           0                         0
# 3                 2                          11                         9
# 4                 3                           0                         0
# ...             ...                         ...                       ...
# 103899            2                           3                         0
# 103900            4                           0                         0
# 103901            4                           7                        14
# 103902            1                           0                         0
# 103903            1                           0                         0
#
#         Gender_Male  Customer Type_disloyal Customer  \
# 0                 1                                0
# 1                 1                                1
# 2                 0                                0
# 3                 0                                0
# 4                 1                                0
# ...             ...                              ...
# 103899            0                                1
# 103900            1                                0
# 103901            1                                1
# 103902            0                                1
# 103903            1                                0
#
#         Type of Travel_Personal Travel  Class_Eco  Class_Eco Plus  \
# 0                                    1          0               1
# 1                                    0          0               0
# 2                                    0          0               0
# 3                                    0          0               0
# 4                                    0          0               0
# ...                                ...        ...             ...
# 103899                               0          1               0
# 103900                               0          0               0
# 103901                               0          0               0
# 103902                               0          1               0
# 103903                               0          0               0
#
#         satisfaction_satisfied
# 0                            0
# 1                            0
# 2                            1
# 3                            0
# 4                            1
# ...                        ...
# 103899                       0
# 103900                       1
# 103901                       0
# 103902                       0
# 103903                       0
#
# [103594 rows x 13 columns]

# %%
df2=pd.get_dummies(df,drop_first="if_binary").astype(int)

# %%
df2.head()
# Out:
#    Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 0   13              460                       5                 4
# 1   25              235                       1                 3
# 2   26             1142                       5                 4
# 3   25              562                       2                 3
# 4   61              214                       3                 4
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0            5                          25                        18
# 1            1                           1                         6
# 2            5                           0                         0
# 3            2                          11                         9
# 4            3                           0                         0
#
#    Gender_Male  Customer Type_disloyal Customer  \
# 0            1                                0
# 1            1                                1
# 2            0                                0
# 3            0                                0
# 4            1                                0
#
#    Type of Travel_Personal Travel  Class_Eco  Class_Eco Plus  \
# 0                               1          0               1
# 1                               0          0               0
# 2                               0          0               0
# 3                               0          0               0
# 4                               0          0               0
#
#    satisfaction_satisfied
# 0                       0
# 1                       0
# 2                       1
# 3                       0
# 4                       1

# %%
df2.isnull().sum()
# Out:
# Age                                0
# Flight Distance                    0
# Inflight entertainment             0
# Baggage handling                   0
# Cleanliness                        0
# Departure Delay in Minutes         0
# Arrival Delay in Minutes           0
# Gender_Male                        0
# Customer Type_disloyal Customer    0
# Type of Travel_Personal Travel     0
# Class_Eco                          0
# Class_Eco Plus                     0
# satisfaction_satisfied             0
# dtype: int64

# %%
# x and y split
x = df2.drop("satisfaction_satisfied",axis='columns')   # independent variables
y = df2[["satisfaction_satisfied"]]   # target variable

# %%
# training and testing split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lgr = LogisticRegression()

# %%
lgr.fit(x_train,y_train)
# Out:
# c:\Users\kulde\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\kulde\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
x_train
# Out:
#        Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 25869   39             2374                       4                 4
# 34603   68              805                       2                 4
# 95685   25             2454                       4                 4
# 81046   68              950                       3                 3
# 53342   44             2475                       4                 4
# ...    ...              ...                     ...               ...
# 54403   14              622                       4                 5
# 80837   22              403                       2                 5
# 89987   64              280                       1                 2
# 61085   63              950                       5                 5
# 19810   58             2053                       5                 5
#
#        Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 25869            5                           0                         0
# 34603            2                           0                         0
# 95685            2                           0                         1
# 81046            4                           0                         0
# 53342            5                          18                         0
# ...            ...                         ...                       ...
# 54403            4                           0                         0
# 80837            2                           0                         0
# 89987            1                           0                         0
# 61085            5                           1                         0
# 19810            3                          10                         8
#
#        Gender_Male  Customer Type_disloyal Customer  \
# 25869            1                                0
# 34603            1                                0
# 95685            1                                1
# 81046            0                                0
# 53342            0                                0
# ...            ...                              ...
# 54403            1                                0
# 80837            1                                1
# 89987            1                                0
# 61085            1                                0
# 19810            0                                0
#
#        Type of Travel_Personal Travel  Class_Eco  Class_Eco Plus
# 25869                               0          0               0
# 34603                               0          1               0
# 95685                               0          0               0
# 81046                               1          0               1
# 53342                               0          0               0
# ...                               ...        ...             ...
# 54403                               1          0               1
# 80837                               0          1               0
# 89987                               1          1               0
# 61085                               1          1               0
# 19810                               0          0               0
#
# [82875 rows x 12 columns]

# %%
y_train
# Out:
#        satisfaction_satisfied
# 25869                       1
# 34603                       0
# 95685                       1
# 81046                       0
# 53342                       1
# ...                       ...
# 54403                       0
# 80837                       0
# 89987                       0
# 61085                       0
# 19810                       1
#
# [82875 rows x 1 columns]

# %%
y_test
# Out:
#         satisfaction_satisfied
# 21471                        1
# 21736                        1
# 1611                         0
# 5398                         0
# 77985                        1
# ...                        ...
# 37520                        0
# 84951                        1
# 72556                        1
# 101495                       1
# 54654                        0
#
# [20719 rows x 1 columns]

# %%
x_test
# Out:
#         Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 21471    37             2586                       3                 5
# 21736    48              416                       4                 4
# 1611     34              860                       3                 2
# 5398     36              308                       2                 5
# 77985    51              356                       5                 5
# ...     ...              ...                     ...               ...
# 37520    46              587                       1                 1
# 84951    23             3917                       5                 4
# 72556    48             1947                       4                 4
# 101495   44             3284                       4                 4
# 54654    45             1749                       4                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 21471             5                          27                        14
# 21736             1                          21                         6
# 1611              3                           0                         0
# 5398              2                          22                        23
# 77985             5                           0                         0
# ...             ...                         ...                       ...
# 37520             3                          21                        15
# 84951             5                           0                         0
# 72556             4                          11                         2
# 101495            5                           0                         0
# 54654             4                           0                         0
#
#         Gender_Male  Customer Type_disloyal Customer  \
# 21471             1                                0
# 21736             0                                0
# 1611              1                                1
# 5398              1                                0
# 77985             0                                0
# ...             ...                              ...
# 37520             0                                0
# 84951             0                                0
# 72556             0                                0
# 101495            1                                0
# 54654             1                                0
#
#         Type of Travel_Personal Travel  Class_Eco  Class_Eco Plus
# 21471                                0          0               0
# 21736                                0          1               0
# 1611                                 0          1               0
# 5398                                 1          1               0
# 77985                                0          0               0
# ...                                ...        ...             ...
# 37520                                1          0               0
# 84951                                0          0               0
# 72556                                0          0               0
# 101495                               0          0               0
# 54654                                0          1               0
#
# [20719 rows x 12 columns]

# %%
lgr.score(x_train,y_train)
# Out:
# 0.79852790346908

# %%
lgr.score(x_test,y_test)
# Out:
# 0.8021622665186544

# %%
print("Training Score:",lgr.score(x_train,y_train)*100)
print("Testing Score:",lgr.score(x_test,y_test)*100)
# Out:
# Training Score: 79.852790346908
# Testing Score: 80.21622665186544

# %%
pred = lgr.predict(x_test)

# %%
x_test.shape
# Out:
# (20719, 12)

# %%
pred
# Out:
# array([1, 1, 0, ..., 1, 1, 0])

# %%
y_test['prediction'] = pred

# %%
y_test.head(30)
# Out:
#         satisfaction_satisfied  prediction
# 21471                        1           1
# 21736                        1           1
# 1611                         0           0
# 5398                         0           0
# 77985                        1           1
# 6452                         0           0
# 72158                        1           1
# 51357                        1           1
# 20336                        0           0
# 101574                       1           1
# 6845                         1           1
# 25023                        1           1
# 74933                        1           0
# 39093                        1           1
# 49315                        1           0
# 33578                        0           1
# 64733                        0           1
# 8982                         1           1
# 82116                        1           1
# 84016                        1           1
# 56004                        1           1
# 73408                        1           1
# 95461                        1           0
# 62785                        0           0
# 85270                        0           1
# 65915                        0           1
# 1458                         0           0
# 98282                        0           1
# 77954                        1           1
# 19444                        0           1

# %%
# model evaluation

from sklearn.metrics import confusion_matrix,classification_report

# %%
matrix = confusion_matrix(y_test['satisfaction_satisfied'],y_test['prediction'])
matrix
# Out:
# array([[9610, 1975],
#        [2124, 7010]])

# %%
y_test['prediction']
# Out:
# 21471     1
# 21736     1
# 1611      0
# 5398      0
# 77985     1
#          ..
# 37520     0
# 84951     1
# 72556     1
# 101495    1
# 54654     0
# Name: prediction, Length: 20719, dtype: int64

# %%
y_test['satisfaction_satisfied']
# Out:
# 21471     1
# 21736     1
# 1611      0
# 5398      0
# 77985     1
#          ..
# 37520     0
# 84951     1
# 72556     1
# 101495    1
# 54654     0
# Name: satisfaction_satisfied, Length: 20719, dtype: int64

# %%
sns.heatmap(matrix,annot=True,fmt='d')
plt.title('confusion_matrix')
plt.axis('off')
plt.show()

# %%
import os , joblib

# %%
os.makedirs('models',exist_ok=True)
joblib.dump(lgr,'./models/logisticregre.lb')
print('your model is saved')
# Out:
# your model is saved

# %%
print(classification_report(y_test['satisfaction_satisfied'],y_test['prediction']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.82     11585
#            1       0.78      0.77      0.77      9134
#
#     accuracy                           0.80     20719
#    macro avg       0.80      0.80      0.80     20719
# weighted avg       0.80      0.80      0.80     20719

# %%
y_test
# Out:
#         satisfaction_satisfied  prediction
# 21471                        1           1
# 21736                        1           1
# 1611                         0           0
# 5398                         0           0
# 77985                        1           1
# ...                        ...         ...
# 37520                        0           0
# 84951                        1           1
# 72556                        1           1
# 101495                       1           1
# 54654                        0           0
#
# [20719 rows x 2 columns]

# %%
##    Try with decisiontree and randomforest


from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor

# %%
dtc = DecisionTreeClassifier()
rdf = RandomForestClassifier()

# %%
# training algorithm
dtc.fit(x_train,y_train)
rdf.fit(x_train,y_train)
print('your algorithms is trained')
# Out:
# your algorithms is trained

# %%
print("Decision tree score ") 
print("Training score : ",dtc.score(x_train,y_train)*100 )
print("Testing score : " ,dtc.score(x_test,y_test['satisfaction_satisfied'])*100)


print()
print("RandomForest score")
print("Training score : ",rdf.score(x_train,y_train)*100)
print("Testing score : " ,rdf.score(x_test,y_test['satisfaction_satisfied'])*100)
# Out:
# Decision tree score
# Training score :  99.96862745098039
# Testing score :  81.62073459143781
#
# RandomForest score
# Training score :  99.96259426847662
# Testing score :  87.18084849654906

# %%
# saving models
import os,joblib

os.makedirs('models',exist_ok=True)
joblib.dump(dtc,'./models/decisiontree.lb')
joblib.dump(rdf,'./models/randomforest.lb')

print('your model is saved')
# Out:
# your model is saved

# %%
## for checking the accuracy
# hyperparameter turning
# n_estimators=80,200 but score are same no change the score

rdf2 = RandomForestClassifier(n_estimators=80,max_depth=12,min_samples_split=45)

# %%
rdf2.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=12, min_samples_split=45, n_estimators=80)

# %%
print("RandomForest score")
print("Training score : ",rdf2.score(x_train,y_train)*100)
print("Testing score : " ,rdf2.score(x_test,y_test['satisfaction_satisfied'])*100)
# Out:
# RandomForest score
# Training score :  88.34630467571644
# Testing score :  88.22819634152226

# %%
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV
from sklearn.ensemble import RandomForestClassifier
rdf3 = RandomForestClassifier()

# %%
parameters = {'n_estimators':[85,95,105,115],
              'max_depth':[9,15,21,27],
              'min_samples_split':[45,35,55]}

gridsearchcv = GridSearchCV(estimator=rdf3,param_grid=parameters)

# %%
gridsearchcv.fit(x_train,y_train)

# %%
gridsearchcv.best_params_
# Out:
# {'max_depth': 15, 'min_samples_split': 55, 'n_estimators': 85}

# %%
rdf4 = RandomForestClassifier()

# %%
rdf4.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
print("RandomForest score")
print("Training score : ",rdf4.score(x_train,y_train)*100)
print("Testing score : " ,rdf4.score(x_test,y_test['satisfaction_satisfied'])*100)
# Out:
# RandomForest score
# Training score :  99.96742081447964
# Testing score :  86.95400357160095
